# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv("/content/spam.csv",encoding='latin-1')

# %%
data
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN
#
# [5572 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['v1']=le.fit_transform(data['v1'])
data['v2']=le.fit_transform(data['v2'])
data['Unnamed: 2']=le.fit_transform(data['Unnamed: 2'])
data['Unnamed: 3']=le.fit_transform(data['Unnamed: 3'])
data['Unnamed: 4']=le.fit_transform(data['Unnamed: 4'])

# %%
data
# Out:
#       v1    v2  Unnamed: 2  Unnamed: 3  Unnamed: 4
# 0      0  1079          43          10           5
# 1      0  3101          43          10           5
# 2      1  1000          43          10           5
# 3      0  4088          43          10           5
# 4      0  2757          43          10           5
# ...   ..   ...         ...         ...         ...
# 5567   1  3992          43          10           5
# 5568   0  4560          43          10           5
# 5569   0  3286          43          10           5
# 5570   0  3901          43          10           5
# 5571   0  3409          43          10           5
#
# [5572 rows x 5 columns]

# %%
x=data.iloc[:,[0,2,3,4]]
y=data.iloc[:,-1]

# %%
x
# Out:
#       v1  Unnamed: 2  Unnamed: 3  Unnamed: 4
# 0      0          43          10           5
# 1      0          43          10           5
# 2      1          43          10           5
# 3      0          43          10           5
# 4      0          43          10           5
# ...   ..         ...         ...         ...
# 5567   1          43          10           5
# 5568   0          43          10           5
# 5569   0          43          10           5
# 5570   0          43          10           5
# 5571   0          43          10           5
#
# [5572 rows x 4 columns]

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#        ..
# 5567    5
# 5568    5
# 5569    5
# 5570    5
# 5571    5
# Name: Unnamed: 4, Length: 5572, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
Se=StandardScaler()
x_train=Se.fit_transform(x_train)
x_test=Se.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=gnb.predict(x_test)

# %%
from sklearn import metrics
print("Gaussian Naive Bayes model accuracy(in %):",metrics.accuracy_score(y_test,y_pred)*100)
# Out:
# Gaussian Naive Bayes model accuracy(in %): 100.0
